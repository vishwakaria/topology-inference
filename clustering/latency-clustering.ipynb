# %%
# !pip install scikit-learn-extra
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 10.0 MB/s
# ...

# %%
import os

latencies = []
with open ("peer_read_latencies.txt", 'r') as f:
    for line in f.readlines():
        latencies.append(line.split())

for row in latencies:
    print(row)
# Out:
# ['0.00', '72.63', '72.01', '71.57', '43.41', '41.51', '36.91']
# ['72.25', '0.00', '39.91', '38.30', '74.53', '72.15', '72.60']
# ['71.85', '39.48', '0.00', '38.75', '74.68', '72.14', '72.32']
# ['71.38', '39.39', '38.82', '0.00', '74.38', '72.11', '72.52']
# ['43.84', '74.96', '74.83', '75.04', '0.00', '44.65', '44.11']
# ['41.61', '72.25', '71.98', '73.08', '44.46', '0.00', '42.49']
# ['36.67', '72.28', '72.04', '72.89', '43.89', '42.52', '0.00']

# %%
from sklearn_extra.cluster import KMedoids

import numpy as np
kmedoids = KMedoids(n_clusters=2, random_state=32).fit(latencies)
print(f" actual:   {kmedoids.labels_}")
print(f" expected: [1 0 0 0 1 1 1]")
# Out:
#  actual:   [1 0 0 0 1 1 1]
#  expected: [1 0 0 0 1 1 1]

# %% [markdown]
# ### Experiments (Ignore)

# %%
import networkx as nx
import numpy as np
import string

dt = [('len', float)]
lat_matrix = np.array(latencies)

G = G=nx.from_numpy_matrix(lat_matrix)
nx.draw(G, with_labels=True)

# %%
## K-means does not accpet a distance matrix, ignore for now

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2)
kmeans.fit(latencies)

plt.scatter(latencies, c=kmeans.labels_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c60c8f059e44> in <module>
#       6 kmeans.fit(latencies)
#       7
# ----> 8 plt.scatter(latencies, c=kmeans.labels_)
#       9 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'
